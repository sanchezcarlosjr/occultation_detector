# %% [markdown]
# # Local Installation

# %%
from IPython.display import clear_output
! cd .. && pip install -e .
clear_output()

# %% [markdown]
# # Imports

# %%
from occultation_detector.pipeline import *

# %% [markdown]
# # Predict occultations with pipeline

# %%
predictor = pipeline('../checkpoints/vanilla-neuronal-network.keras')

# %%
ds = NpyFileLoader('../examples/taosii_circle_simulation_diffraction_profile_9.npy')
ds.plot()

# %%
predictor(ds)
# Out:
# [{'diameter': 0.7033632,
#   'ua': 0.6562469,
#   'toffset': -0.0006595552,
#   'T': -0.0015546754,
#   'b': 0.94797885,
#   'D': 1.6655862,
#   'z': 0.6352129,
#   'R_star': 0.6342468,
#   'type': -0.0028108638}]
